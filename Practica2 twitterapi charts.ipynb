# %%
# !pip install tweepy
# !pip install python-dotenv
# !pip install wordcloud
# Out:
# Requirement already satisfied: tweepy in c:\users\emman\anaconda3\lib\site-packages (4.14.0)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\emman\anaconda3\lib\site-packages (from tweepy) (2.28.1)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in c:\users\emman\anaconda3\lib\site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in c:\users\emman\anaconda3\lib\site-packages (from tweepy) (3.2.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\emman\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\emman\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\emman\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\emman\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2022.9.14)
# Requirement already satisfied: python-dotenv in c:\users\emman\anaconda3\lib\site-packages (1.0.0)
# Collecting wordcloud
#   Downloading wordcloud-1.9.2-cp39-cp39-win_amd64.whl (153 kB)
#      -------------------------------------- 153.3/153.3 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: pillow in c:\users\emman\anaconda3\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\emman\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\emman\anaconda3\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\emman\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\emman\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\emman\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\emman\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\emman\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\emman\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\emman\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2

# %%
# !pip install chartify
# Out:
# Collecting chartify
#   Downloading chartify-4.0.3-py2.py3-none-any.whl (63 kB)
#      ---------------------------------------- 64.0/64.0 kB 3.6 MB/s eta 0:00:00
# Collecting Jinja2>=3.1.0
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Requirement already satisfied: ipython>=7.17.0 in c:\users\emman\anaconda3\lib\site-packages (from chartify) (7.31.1)
# Collecting jupyter-bokeh>=3.0.7
#   Downloading jupyter_bokeh-3.0.7-py3-none-any.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 14.7 MB/s eta 0:00:00
# Collecting bokeh>=3.0.0
#   Downloading bokeh-3.1.1-py3-none-any.whl (8.3 MB)
#      ---------------------------------------- 8.3/8.3 MB 44.0 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\emman\anaconda3\lib\site-packages (from chartify) (6.0)
# Requirement already satisfied: Pillow>=9.1.0 in c:\users\emman\anaconda3\lib\site-packages (from chartify) (9.2.0)
# Requirement already satisfied: ipykernel>=6.0 in c:\users\emman\anaconda3\lib\site-packages (from chartify) (6.15.2)
# Requirement already satisfied: pandas<2.0.0,>=1.2.0 in c:\users\emman\anaconda3\lib\site-packages (from chartify) (1.4.4)
# Collecting selenium>=4.0.0
#   Downloading selenium-4.9.1-py3-none-any.whl (6.6 MB)
#      ---------------------------------------- 6.6/6.6 MB 46.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in c:\users\emman\anaconda3\lib\site-packages (from chartify) (1.9.1)
# Requirement already satisfied: numpy>=1.16 in c:\users\emman\anaconda3\lib\site-packages (from bokeh>=3.0.0->chartify) (1.21.5)
# Collecting xyzservices>=2021.09.1
#   Downloading xyzservices-2023.5.0-py3-none-any.whl (56 kB)
#      ---------------------------------------- 56.5/56.5 kB ? eta 0:00:00
# Requirement already satisfied: packaging>=16.8 in c:\users\emman\anaconda3\lib\site-packages (from bokeh>=3.0.0->chartify) (21.3)
# Requirement already satisfied: tornado>=5.1 in c:\users\emman\anaconda3\lib\site-packages (from bokeh>=3.0.0->chartify) (6.1)
# Collecting contourpy>=1
#   Downloading contourpy-1.0.7-cp39-cp39-win_amd64.whl (160 kB)
#      ---------------------------------------- 160.2/160.2 kB ? eta 0:00:00
# Requirement already satisfied: nest-asyncio in c:\users\emman\anaconda3\lib\site-packages (from ipykernel>=6.0->chartify) (1.5.5)
# Requirement already satisfied: traitlets>=5.1.0 in c:\users\emman\anaconda3\lib\site-packages (from ipykernel>=6.0->chartify) (5.1.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\emman\anaconda3\lib\site-packages (from ipykernel>=6.0->chartify) (7.3.4)
# Requirement already satisfied: debugpy>=1.0 in c:\users\emman\anaconda3\lib\site-packages (from ipykernel>=6.0->chartify) (1.5.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\emman\anaconda3\lib\site-packages (from ipykernel>=6.0->chartify) (23.2.0)
# Requirement already satisfied: psutil in c:\users\emman\anaconda3\lib\site-packages (from ipykernel>=6.0->chartify) (5.9.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\emman\anaconda3\lib\site-packages (from ipykernel>=6.0->chartify) (0.1.6)
# Requirement already satisfied: decorator in c:\users\emman\anaconda3\lib\site-packages (from ipython>=7.17.0->chartify) (5.1.1)
# Requirement already satisfied: pygments in c:\users\emman\anaconda3\lib\site-packages (from ipython>=7.17.0->chartify) (2.11.2)
# Requirement already satisfied: pickleshare in c:\users\emman\anaconda3\lib\site-packages (from ipython>=7.17.0->chartify) (0.7.5)
# Requirement already satisfied: colorama in c:\users\emman\anaconda3\lib\site-packages (from ipython>=7.17.0->chartify) (0.4.5)
# Requirement already satisfied: backcall in c:\users\emman\anaconda3\lib\site-packages (from ipython>=7.17.0->chartify) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\emman\anaconda3\lib\site-packages (from ipython>=7.17.0->chartify) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\emman\anaconda3\lib\site-packages (from ipython>=7.17.0->chartify) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in c:\users\emman\anaconda3\lib\site-packages (from ipython>=7.17.0->chartify) (63.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\emman\anaconda3\lib\site-packages (from Jinja2>=3.1.0->chartify) (2.0.1)
# Collecting ipywidgets==8.*
#   Using cached ipywidgets-8.0.6-py3-none-any.whl (138 kB)
# Collecting widgetsnbextension~=4.0.7
#   Using cached widgetsnbextension-4.0.7-py3-none-any.whl (2.1 MB)
# Collecting jupyterlab-widgets~=3.0.7
#   Using cached jupyterlab_widgets-3.0.7-py3-none-any.whl (198 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\emman\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.2.0->chartify) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\emman\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.2.0->chartify) (2022.1)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.10.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\emman\anaconda3\lib\site-packages (from selenium>=4.0.0->chartify) (1.26.11)
# Collecting trio~=0.17
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
#      ---------------------------------------- 384.9/384.9 kB ? eta 0:00:00
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\emman\anaconda3\lib\site-packages (from selenium>=4.0.0->chartify) (2022.9.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\emman\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.17.0->chartify) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\emman\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=6.0->chartify) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\emman\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=6.0->chartify) (4.11.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\emman\anaconda3\lib\site-packages (from packaging>=16.8->bokeh>=3.0.0->chartify) (3.0.9)
# Requirement already satisfied: wcwidth in c:\users\emman\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.17.0->chartify) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\emman\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.2.0->chartify) (1.16.0)
# Requirement already satisfied: idna in c:\users\emman\anaconda3\lib\site-packages (from trio~=0.17->selenium>=4.0.0->chartify) (3.3)
# Requirement already satisfied: cffi>=1.14 in c:\users\emman\anaconda3\lib\site-packages (from trio~=0.17->selenium>=4.0.0->chartify) (1.15.1)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\emman\anaconda3\lib\site-packages (from trio~=0.17->selenium>=4.0.0->chartify) (21.4.0)
# Requirement already satisfied: sortedcontainers in c:\users\emman\anaconda3\lib\site-packages (from trio~=0.17->selenium>=4.0.0->chartify) (2.4.0)
# Requirement already satisfied: sniffio in c:\users\emman\anaconda3\lib\site-packages (from trio~=0.17->selenium>=4.0.0->chartify) (1.2.0)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Collecting exceptiongroup>=1.0.0rc9
#   Downloading exceptiongroup-1.1.1-py3-none-any.whl (14 kB)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\emman\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium>=4.0.0->chartify) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\emman\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium>=4.0.0->chartify) (2.21)
# Requirement already satisfied: pywin32>=1.0 in c:\users\emman\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=6.0->chartify) (302)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.3/58.3 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: xyzservices, widgetsnbextension, outcome, jupyterlab-widgets, Jinja2, h11, exceptiongroup, contourpy, async-generator, wsproto, trio, trio-websocket, bokeh, selenium, ipywidgets, jupyter-bokeh, chartify
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.5.2
#     Uninstalling widgetsnbextension-3.5.2:
#       Successfully uninstalled widgetsnbextension-3.5.2
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 1.0.0
#     Uninstalling jupyterlab-widgets-1.0.0:
#       Successfully uninstalled jupyterlab-widgets-1.0.0
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 2.4.3
#     Uninstalling bokeh-2.4.3:
#       Successfully uninstalled bokeh-2.4.3
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.6.5
#     Uninstalling ipywidgets-7.6.5:
#       Successfully uninstalled ipywidgets-7.6.5
# Successfully installed Jinja2-3.1.2 async-generator-1.10 bokeh-3.1.1 chartify-4.0.3 contourpy-1.0.7 exceptiongroup-1.1.1 h11-0.14.0 ipywidgets-8.0.6 jupyter-bokeh-3.0.7 jupyterlab-widgets-3.0.7 outcome-1.2.0 selenium-4.9.1 trio-0.22.0 trio-websocket-0.10.2 widgetsnbextension-4.0.7 wsproto-1.2.0 xyzservices-2023.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.11.1 requires ruamel-yaml, which is not installed.
# panel 0.13.1 requires bokeh<2.5.0,>=2.4.0, but you have bokeh 3.1.1 which is incompatible.

# %%
import os
import tweepy
from dotenv import load_dotenv
import pandas as pd
load_dotenv()
consumer_key = os.environ["API_KEY"]
consumer_secret = os.environ["API_KEY_SECRET"]
access_token = os.environ["ACCESS_TOKEN"]
access_token_secret = os.environ["ACCESS_TOKEN_SECRET"]

auth = tweepy.OAuth1UserHandler(
  consumer_key, 
  consumer_secret, 
  access_token, 
  access_token_secret
)

api = tweepy.API(auth)

# %%
# function to display data of each tweet
def printtweetdata(n, ith_tweet):
        print()
        print(f"Tweet {n}:")
        print(f"Username:{ith_tweet[0]}")
        print(f"Description:{ith_tweet[1]}")
        print(f"Location:{ith_tweet[2]}")
        print(f"Following Count:{ith_tweet[3]}")
        print(f"Follower Count:{ith_tweet[4]}")
        print(f"Total Tweets:{ith_tweet[5]}")
        print(f"Retweet Count:{ith_tweet[6]}")
        print(f"Tweet Text:{ith_tweet[7]}")
        print(f"Hashtags Used:{ith_tweet[8]}")
 
 
# function to perform data extraction
def scrape(words, date_since, numtweet):
 
        # Creating DataFrame using pandas
        db = pd.DataFrame(columns=['username',
                                   'description',
                                   'location',
                                   'following',
                                   'followers',
                                   'totaltweets',
                                   'retweetcount',
                                   'text',
                                   'hashtags'])
 
        # We are using .Cursor() to search
        # through twitter for the required tweets.
        # The number of tweets can be
        # restricted using .items(number of tweets)
        tweets = tweepy.Cursor(api.search_tweets,
                               words, lang="en",
                               since_id=date_since,
                               tweet_mode='extended').items(numtweet)
 
 
        # .Cursor() returns an iterable object. Each item in
        # the iterator has various attributes
        # that you can access to
        # get information about each tweet
        list_tweets = [tweet for tweet in tweets]
 
        # Counter to maintain Tweet Count
        i = 1
 
        # we will iterate over each tweet in the
        # list for extracting information about each tweet
        for tweet in list_tweets:
                username = tweet.user.screen_name
                description = tweet.user.description
                location = tweet.user.location
                following = tweet.user.friends_count
                followers = tweet.user.followers_count
                totaltweets = tweet.user.statuses_count
                retweetcount = tweet.retweet_count
                hashtags = tweet.entities['hashtags']
 
                # Retweets can be distinguished by
                # a retweeted_status attribute,
                # in case it is an invalid reference,
                # except block will be executed
                try:
                        text = tweet.retweeted_status.full_text
                except AttributeError:
                        text = tweet.full_text
                hashtext = list()
                for j in range(0, len(hashtags)):
                        hashtext.append(hashtags[j]['text'])
 
                # Here we are appending all the
                # extracted information in the DataFrame
                ith_tweet = [username, description,
                             location, following,
                             followers, totaltweets,
                             retweetcount, text, hashtext]
                db.loc[len(db)] = ith_tweet
 
                # Function call to print tweet data on screen
                #printtweetdata(i, ith_tweet)
                i = i+1
        filename = 'scraped_tweets.csv'
 
        # we will save our database as a CSV file.
        return db

# %%
df = scrape('#war', '2023-05-05', 50)
df.head(10)
# Out:
#           username                                        description  \
# 0       JCrochunis  Love my country, Joe Biden Is NOT My President...
# 1        ewebhines
# 2    marce64693805                             Hincha de Boca Juniors
# 3  orangepallmall2  Part time vampire.\nAttacked, but still standi...
# 4  CarranzaYazman1  |hello No-Surviv I am a beyblade fan | I’m 🇺🇸/...
# 5        rogabooks  Selling Rare Books & Manuscripts from the 15th...
# 6      Chaganistan  Father, teacher, anti-imperialist, eco-sociali...
#
#             location  following  followers  totaltweets  retweetcount  \
# 0  Pennsylvania, USA       3932       2124       225965           223
# 1                           152        151         7984            68
# 2                            47         13         1336             0
# 3          Out Wesht        337        182         4672             8
# 4    Shut up avenue        3012        513        10158             8
# 5         Naples, FL         19        205           34             0
# 6    Weston, Toronto       1299        618         4614            14
#
#                                                 text  \
# 0  🇬🇧|At the #G7 meeting with the #USA and #EU, w...
# 1  Put aside your affiliations and rhetoric.\n\nW...
# 2  russia has fired 8,000 missiles of various typ...
# 3  Tell me there's no russian propaganda on here ...
# 4  Tell me there's no russian propaganda on here ...
# 5  https://t.co/5SErZde1Hb\nENDING SOON NO RESERV...
# 6  A friendly reminder to the world: There is not...
#
#                                             hashtags
# 0                              [G7, USA, EU, Russia]
# 1                                                 []
# 2                                                 []
# 3        [Ukraine, Russia, War, NAFO, NATO, Bakhmut]
# 4        [Ukraine, Russia, War, NAFO, NATO, Bakhmut]
# 5  [book, books, history, love, biblio, biography...
# 6                                         [Canadian]

# %%
import chartify  
# Plot the data
df_first_20 = df.head(20)    
ch = chartify.Chart(blank_labels=True)    
ch.plot.scatter(
        data_frame=df_first_20,
        x_column="following",
        y_column="retweetcount",
        color_column="username",
)
ch.style.color_palette.reset_palette_order()
ch.plot.text(
        data_frame=df_first_20,
        x_column="following",
        y_column="retweetcount",
        text_column="username",
        color_column="username",
        x_offset=1,
        y_offset=-1,
        font_size="10pt",
)
ch.set_title("Text")
ch.set_subtitle("Labels for specific observations.")
ch.show()
# Out:
#   <div id="c17845c4-951a-406a-b2c4-98cc46660ab9" data-root-id="p4075" style="display: contents;"></div>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style(style='whitegrid')


sns.scatterplot(
    data=df_first_20, 
    x='following', 
    y='retweetcount', 
    hue='username'
    )

plt.title('Exploring first 20 users with scatterplot')
plt.xlabel('Following')
plt.ylabel('Retweet Count')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

plt.show()

# %%
# Barplot using chartify , one big difference is the bars are ordered by internally

ch = chartify.Chart(blank_labels=True, x_axis_type='categorical')
ch.set_title("Users with most retweet count")

ch.plot.bar(
        data_frame=df_first_20,
        categorical_columns=['username'],
        numeric_column='retweetcount')
ch.show()
# Out:
#   <div id="dda378f9-776b-4e09-8a09-08484c6059ed" data-root-id="p5430" style="display: contents;"></div>

# %%
## Barplot using seaborn, difference is seaborn doesnt apply any order in the plot

plt.figure(figsize=(15,8))
sns.barplot(x = 'username', y = 'retweetcount', data = df_first_20,
            label = 'Total', color = 'b', edgecolor = 'w')
# Out:
# <AxesSubplot:xlabel='username', ylabel='retweetcount'>

# %%
(
chartify.Chart(blank_labels=True, x_axis_type="categorical")
        .set_title("Stacked bar chart")
        .plot.bar_stacked(
            data_frame=df,
            categorical_columns=["location"],
            numeric_column="totaltweets",
            stack_column="username",
            normalize=False,
        ).show()
    )
# Out:
#   <div id="b9395165-0e7b-40a3-96d0-1a275f00e662" data-root-id="p7384" style="display: contents;"></div>

# %%
from wordcloud import WordCloud

# %%
col_list = df.text.values.tolist()
text = ''.join(col_list)

# %%
##to-do remove stop words
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()
